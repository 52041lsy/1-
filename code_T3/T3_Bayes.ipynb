# %%
import pandas as pd
import numpy as np
from pmdarima import auto_arima
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.stattools import adfuller

# %%
# 读取数据
df_csv = pd.read_csv('df_past_order_with_cluster_im.csv', index_col=0, parse_dates=True)
df_csv.drop('SKU', axis=1, inplace=True)
# 转置
df_csv = df_csv.T

# 将数据集划分为训练集和测试集
train = df_csv.loc['2016-06-01':'2016-06-18']
test = df_csv.loc['2016-06-19':'2016-06-23']  # 注意这里日期范围的调整
sum=0
# 遍历每一列进行预测
for col in train.columns:
    train_data = train[col]
    test_data = test[col]
    train_data_array = train_data.values.flatten()
    train_data_array = train_data_array.astype('float32')
    test_data_array = test_data.values.flatten()
    test_data_array = test_data_array.astype('float32') 
    
    # 检验数据是否平稳
    adf_result = adfuller(train_data_array)
    print(f'ADF Statistic: {adf_result[0]}')
    print(f'p-value: {adf_result[1]}')
    print(f'Critical Values: {adf_result[4]}')
    
    # 建立贝叶斯 ARIMA 模型
    model = auto_arima(train_data_array, 
                       m=1,  # 因为数据是日数据
                       start_p=1,
                       start_q=1,
                       max_p=6,
                       max_q=6,
                       d=1,  # 因为数据可能已经是一阶差分的
                       seasonal=False,  # 假设数据没有季节性
                       stepwise=True,
                       error_action='ignore',
                       n_fits=10,
                       trace=True)
    
    # 进行预测
    predictions = model.predict(n_periods=len(test_data_array))
    
    # 计算RMSE
    rmse = np.sqrt(mean_squared_error(test_data_array, predictions))
    sum+=rmse
    print(f'预测值 for {col}: {predictions}')
    print(f'真实值 for {col}: {test_data_array}')
    print(f'RMSE for {col}: {rmse}')
    print('-------------------------')
temp=sum/106
print({sum})
print({temp})
# Out:
# /tmp/ipykernel_79270/2528421899.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_csv = pd.read_csv('df_past_order_with_cluster_im.csv', index_col=0, parse_dates=True)
# ADF Statistic: -3.8446077249963695
# p-value: 0.002482512301067748
# Critical Values: {'1%': -3.9644434814814815, '5%': -3.0849081481481484, '10%': -2.6818144444444445}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.27 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=202.405, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=203.905, Time=0.04 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=203.739, Time=0.04 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=200.433, Time=0.01 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.424 seconds
# 预测值 for shang-hai-shi: [484. 484. 484. 484. 484.]
# 真实值 for shang-hai-shi: [559.  499.9 457.5 448.8 449. ]
# RMSE for shang-hai-shi: 42.53022611104575
# -------------------------
# ADF Statistic: -0.9966860880472832
# p-value: 0.7544710545893367
# Critical Values: {'1%': -4.331573, '5%': -3.23295, '10%': -2.7487}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=95.942, Time=0.04 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=96.049, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=97.479, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=95.025, Time=0.02 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=94.069, Time=0.01 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.110 seconds
# 预测值 for shang-rao-shi: [12.30000019 12.30000019 12.30000019 12.30000019 12.30000019]
# 真实值 for shang-rao-shi: [17.8 18.4  9.5  8.1  8.5]
# RMSE for shang-rao-shi: 4.634220181308074
# -------------------------
# ADF Statistic: -2.4392998070525187
# p-value: 0.13095007616156307
# Critical Values: {'1%': -4.331573, '5%': -3.23295, '10%': -2.7487}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.09 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=145.928, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=147.837, Time=0.04 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=147.731, Time=0.04 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=143.932, Time=0.01 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.182 seconds
# 预测值 for dong-guan-shi: [55.09999847 55.09999847 55.09999847 55.09999847 55.09999847]
# 真实值 for dong-guan-shi: [71.9 70.9 43.6 32.5 44.6]
# RMSE for dong-guan-shi: 16.03209362500671
# -------------------------
# ADF Statistic: -15.614677502942296
# p-value: 1.762106618716181e-28
# Critical Values: {'1%': -4.137829282407408, '5%': -3.1549724074074077, '10%': -2.7144769444444443}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.10 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=120.394, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=122.167, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=121.753, Time=0.02 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=118.469, Time=0.01 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.171 seconds
# 预测值 for dong-ying-shi: [19. 19. 19. 19. 19.]
# 真实值 for dong-ying-shi: [28.5 28.2 11.3  9.8 10.3]
# RMSE for dong-ying-shi: 8.88267982393221
# -------------------------
# ADF Statistic: -7.253070964060941
# p-value: 1.7593620262495913e-10
# Critical Values: {'1%': -4.137829282407408, '5%': -3.1549724074074077, '10%': -2.7144769444444443}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.10 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=118.043, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=119.738, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=119.258, Time=0.04 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=116.070, Time=0.02 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.198 seconds
# 预测值 for zhong-shan-shi: [20.29999924 20.29999924 20.29999924 20.29999924 20.29999924]
# 真实值 for zhong-shan-shi: [28.5 29.3 14.5 12.9 15.2]
# RMSE for zhong-shan-shi: 7.247758166217637
# -------------------------
# ADF Statistic: -1.6121636588640056
# p-value: 0.4768399069765186
# Critical Values: {'1%': -4.331573, '5%': -3.23295, '10%': -2.7487}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.10 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=88.928, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=90.820, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=89.160, Time=0.02 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=86.981, Time=0.01 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.164 seconds
# 预测值 for lin-fen-shi: [12.39999962 12.39999962 12.39999962 12.39999962 12.39999962]
# 真实值 for lin-fen-shi: [13.7 13.2  8.2  8.7  6.7]
# RMSE for lin-fen-shi: 3.637306575286123
# -------------------------
# ADF Statistic: 2.179285124066367
# p-value: 0.998865023738246
# Critical Values: {'1%': -4.331573, '5%': -3.23295, '10%': -2.7487}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.12 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=123.647, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=125.581, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.05 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=121.750, Time=0.01 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.211 seconds
# 预测值 for lin-yi-shi: [32. 32. 32. 32. 32.]
# 真实值 for lin-yi-shi: [46.9 44.3 22.  22.6 22.8]
# RMSE for lin-yi-shi: 11.369257087156923
# -------------------------
# ADF Statistic: -2.4536409620807342
# p-value: 0.1271651432640581
# Critical Values: {'1%': -4.331573, '5%': -3.23295, '10%': -2.7487}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.09 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=103.873, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=105.867, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=105.850, Time=0.02 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=101.901, Time=0.02 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.169 seconds
# 预测值 for jiu-jiang-shi: [10.89999962 10.89999962 10.89999962 10.89999962 10.89999962]
# 真实值 for jiu-jiang-shi: [17.6 17.7  8.3  9.3  8.4]
# RMSE for jiu-jiang-shi: 4.619524239157914
# -------------------------
# ADF Statistic: -0.6665169662791941
# p-value: 0.8552328478739158
# Critical Values: {'1%': -4.223238279489106, '5%': -3.189368925619835, '10%': -2.729839421487603}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=79.591, Time=0.04 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=76.975, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=78.690, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=77.999, Time=0.02 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=74.980, Time=0.06 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.155 seconds
# 预测值 for bo-zhou-shi: [8.30000019 8.30000019 8.30000019 8.30000019 8.30000019]
# 真实值 for bo-zhou-shi: [12.1 13.2  7.3  8.9  6.7]
# RMSE for bo-zhou-shi: 2.9110135089085354
# -------------------------
# ADF Statistic: 0.19055687681526828
# p-value: 0.9717269566983155
# Critical Values: {'1%': -4.331573, '5%': -3.23295, '10%': -2.7487}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.12 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=150.625, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=152.377, Time=0.04 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=151.875, Time=0.03 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=148.687, Time=0.02 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.228 seconds
# 预测值 for fo-shan-shi: [51. 51. 51. 51. 51.]
# 真实值 for fo-shan-shi: [78.2 75.1 35.6 39.5 25.7]
# RMSE for fo-shan-shi: 21.58772692447892
# -------------------------
# ADF Statistic: -0.05628503293177941
# p-value: 0.9536223603474433
# Critical Values: {'1%': -4.331573, '5%': -3.23295, '10%': -2.7487}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.17 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=119.382, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=121.344, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=121.329, Time=0.03 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=117.397, Time=0.03 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.267 seconds
# 预测值 for bao-ding-shi: [26. 26. 26. 26. 26.]
# 真实值 for bao-ding-shi: [37.8 42.8 23.3 23.6 23.6]
# RMSE for bao-ding-shi: 9.38392196064768
# -------------------------
# ADF Statistic: -1.665072901362588
# p-value: 0.4491918114827745
# Critical Values: {'1%': -4.331573, '5%': -3.23295, '10%': -2.7487}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.08 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=102.611, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=103.948, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=102.530, Time=0.03 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=100.629, Time=0.01 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.160 seconds
# 预测值 for xin-yang-shi: [11.10000038 11.10000038 11.10000038 11.10000038 11.10000038]
# 真实值 for xin-yang-shi: [16.8 18.9  8.3  9.   8.3]
# RMSE for xin-yang-shi: 4.762771856603785
# -------------------------
# ADF Statistic: -2.441247202042556
# p-value: 0.13043140287146032
# Critical Values: {'1%': -4.137829282407408, '5%': -3.1549724074074077, '10%': -2.7144769444444443}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.12 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=79.468, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=81.318, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.07 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=77.666, Time=0.01 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.225 seconds
# 预测值 for lu-an-shi: [16.89999962 16.89999962 16.89999962 16.89999962 16.89999962]
# 真实值 for lu-an-shi: [17.9 17.2 12.3 13.6 12. ]
# RMSE for lu-an-shi: 3.3808279059591877
# -------------------------
# ADF Statistic: 0.29782232963073296
# p-value: 0.9772443553166988
# Critical Values: {'1%': -4.331573, '5%': -3.23295, '10%': -2.7487}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.08 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=105.466, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=107.149, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=106.905, Time=0.02 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=103.475, Time=0.01 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.144 seconds
# 预测值 for lan-zhou-shi: [22.10000038 22.10000038 22.10000038 22.10000038 22.10000038]
# 真实值 for lan-zhou-shi: [31.9 29.4 19.6 19.3 20.5]
# RMSE for lan-zhou-shi: 5.761596680380671
# -------------------------
# ADF Statistic: -4.198516041487504
# p-value: 0.0006627216741328505
# Critical Values: {'1%': -4.137829282407408, '5%': -3.1549724074074077, '10%': -2.7144769444444443}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.13 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=122.796, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=124.069, Time=0.04 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=121.970, Time=0.04 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=120.856, Time=0.01 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.226 seconds
# 预测值 for bao-tou-shi: [18.89999962 18.89999962 18.89999962 18.89999962 18.89999962]
# 真实值 for bao-tou-shi: [29.3 30.6 12.3  9.  12.5]
# RMSE for bao-tou-shi: 9.247486035990544
# -------------------------
# ADF Statistic: -3.1122847174726185
# p-value: 0.025657321271473656
# Critical Values: {'1%': -3.889265672705068, '5%': -3.0543579727254224, '10%': -2.66698384083045}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=189.709, Time=0.06 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=187.444, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=188.023, Time=0.05 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=188.240, Time=0.05 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=185.567, Time=0.01 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.181 seconds
# 预测值 for bei-jing-shi: [354.1000061 354.1000061 354.1000061 354.1000061 354.1000061]
# 真实值 for bei-jing-shi: [419.8 354.6 342.7 291.7 302.9]
# RMSE for bei-jing-shi: 46.82285327298155
# -------------------------
# ADF Statistic: -0.2673436618575096
# p-value: 0.930003793548329
# Critical Values: {'1%': -4.331573, '5%': -3.23295, '10%': -2.7487}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.08 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=162.187, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=164.125, Time=0.04 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=164.071, Time=0.03 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=160.244, Time=0.01 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.172 seconds
# 预测值 for nan-jing-shi: [118.69999695 118.69999695 118.69999695 118.69999695 118.69999695]
# 真实值 for nan-jing-shi: [147.1 155.3 102.8 106.8 107.7]
# RMSE for nan-jing-shi: 23.071803689532388
# -------------------------
# ADF Statistic: 0.4052563644805199
# p-value: 0.9816904497835918
# Critical Values: {'1%': -4.331573, '5%': -3.23295, '10%': -2.7487}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.14 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=126.758, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=128.728, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=128.716, Time=0.02 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=124.819, Time=0.01 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.206 seconds
# 预测值 for nan-ning-shi: [30.10000038 30.10000038 30.10000038 30.10000038 30.10000038]
# 真实值 for nan-ning-shi: [45.4 42.6 25.8 26.2 20.2]
# RMSE for nan-ning-shi: 10.218121027356899
# -------------------------
# ADF Statistic: 681.138171021539
# p-value: 1.0
# Critical Values: {'1%': -4.331573, '5%': -3.23295, '10%': -2.7487}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=131.347, Time=0.05 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=128.569, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=130.328, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=129.968, Time=0.03 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=126.615, Time=0.01 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.126 seconds
# 预测值 for nan-chang-shi: [31.60000038 31.60000038 31.60000038 31.60000038 31.60000038]
# 真实值 for nan-chang-shi: [47.6 41.7 24.3 21.8 22.2]
# RMSE for nan-chang-shi: 10.915126922191073
# -------------------------
# ADF Statistic: -0.7998053462261281
# p-value: 0.8191792390221577
# Critical Values: {'1%': -4.331573, '5%': -3.23295, '10%': -2.7487}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.11 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=149.392, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=150.968, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.04 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=147.401, Time=0.01 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.185 seconds
# 预测值 for nan-tong-shi: [61.5 61.5 61.5 61.5 61.5]
# 真实值 for nan-tong-shi: [81.1 82.6 50.2 46.2 50.2]
# RMSE for nan-tong-shi: 16.240934812766493
# -------------------------
# ADF Statistic: -1.5218552925603988
# p-value: 0.5226734717543767
# Critical Values: {'1%': -4.331573, '5%': -3.23295, '10%': -2.7487}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.08 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=113.698, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=115.205, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=114.450, Time=0.02 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=111.761, Time=0.01 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.139 seconds
# 预测值 for nan-yang-shi: [13.5 13.5 13.5 13.5 13.5]
# 真实值 for nan-yang-shi: [20.8 22.6  7.5  7.1  7.5]
# RMSE for nan-yang-shi: 7.057761642681578
# -------------------------
# ADF Statistic: 1.0542394595008766
# p-value: 0.9948065154781898
# Critical Values: {'1%': -4.223238279489106, '5%': -3.189368925619835, '10%': -2.729839421487603}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.07 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=144.805, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=146.312, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.03 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=142.843, Time=0.01 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.147 seconds
# 预测值 for gang-kou-CDC-suo-zai-cheng-shi: [41.90000153 41.90000153 41.90000153 41.90000153 41.90000153]
# 真实值 for gang-kou-CDC-suo-zai-cheng-shi: [72.  63.9 31.7 28.6 29.3]
# RMSE for gang-kou-CDC-suo-zai-cheng-shi: 19.12955834213415
# -------------------------
# ADF Statistic: -3.4529898392664724
# p-value: 0.009279753356343482
# Critical Values: {'1%': -3.7238633119999998, '5%': -2.98648896, '10%': -2.6328004}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.12 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=264.225, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=247.188, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=256.168, Time=0.02 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=262.226, Time=0.01 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=241.117, Time=0.03 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=240.927, Time=0.04 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : AIC=241.867, Time=0.05 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.14 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.14 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.14 sec
#  ARIMA(3,1,0)(0,0,0)[0]             : AIC=238.946, Time=0.03 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=239.139, Time=0.03 sec
#  ARIMA(4,1,0)(0,0,0)[0]             : AIC=239.887, Time=0.06 sec
#  ARIMA(3,1,1)(0,0,0)[0]             : AIC=inf, Time=0.11 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=inf, Time=0.11 sec
#  ARIMA(4,1,1)(0,0,0)[0]             : AIC=inf, Time=0.14 sec
#
# Best model:  ARIMA(3,1,0)(0,0,0)[0]
# Total fit time: 1.187 seconds
# 预测值 for tai-zhou-shi: [30.95303869 22.13163508 29.61280871 22.35633737 29.14564116 22.88975157
#  28.78363399 23.29552364 28.41515743 23.6285425 ]
# 真实值 for tai-zhou-shi: [41.9 33.5 38.1 32.9 23.5 16.3 23.8 13.9 22.2 15. ]
# RMSE for tai-zhou-shi: 8.566022793350662
# -------------------------
# ADF Statistic: -2.8731054784678225
# p-value: 0.04856604176664961
# Critical Values: {'1%': -4.223238279489106, '5%': -3.189368925619835, '10%': -2.729839421487603}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.05 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=144.925, Time=0.00 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=146.873, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.04 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=142.969, Time=0.00 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.114 seconds
# 预测值 for he-fei-shi: [89.90000153 89.90000153 89.90000153 89.90000153 89.90000153]
# 真实值 for he-fei-shi: [100.1  92.6  66.2  69.3  68. ]
# RMSE for he-fei-shi: 17.759448990393583
# -------------------------
# ADF Statistic: -0.5924499422607086
# p-value: 0.8726789204444942
# Critical Values: {'1%': -4.331573, '5%': -3.23295, '10%': -2.7487}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.06 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=107.043, Time=0.00 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=108.483, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=107.706, Time=0.01 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=105.107, Time=0.01 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.097 seconds
# 预测值 for ji-lin-shi: [13.89999962 13.89999962 13.89999962 13.89999962 13.89999962]
# 真实值 for ji-lin-shi: [21.1 20.2  9.8  9.5  8. ]
# RMSE for ji-lin-shi: 5.701052759895005
# -------------------------
# ADF Statistic: -1.2037664995085042
# p-value: 0.6719733638196039
# Critical Values: {'1%': -4.331573, '5%': -3.23295, '10%': -2.7487}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.07 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=105.140, Time=0.00 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=107.048, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=106.857, Time=0.01 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=103.206, Time=0.01 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.116 seconds
# 预测值 for zhou-kou-shi: [12.60000038 12.60000038 12.60000038 12.60000038 12.60000038]
# 真实值 for zhou-kou-shi: [18.5 18.   9.   9.4  7.6]
# RMSE for zhou-kou-shi: 4.7364544498295675
# -------------------------
# ADF Statistic: -3.7324685231254664
# p-value: 0.0036789542569975594
# Critical Values: {'1%': -4.01203360058309, '5%': -3.1041838775510207, '10%': -2.6909873469387753}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.07 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=123.079, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=124.883, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=124.832, Time=0.02 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=121.140, Time=0.01 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.123 seconds
# 预测值 for hu-he-hao-te-shi: [29.39999962 29.39999962 29.39999962 29.39999962 29.39999962]
# 真实值 for hu-he-hao-te-shi: [40.7 38.8 25.8 27.8 24.5]
# RMSE for hu-he-hao-te-shi: 7.149545704740971
# -------------------------
# ADF Statistic: -11.971786754723475
# p-value: 3.883093829017519e-22
# Critical Values: {'1%': -4.137829282407408, '5%': -3.1549724074074077, '10%': -2.7144769444444443}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.05 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=107.237, Time=0.00 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=109.140, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=108.740, Time=0.01 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=105.253, Time=0.00 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.083 seconds
# 预测值 for xian-yang-shi: [12.5 12.5 12.5 12.5 12.5]
# 真实值 for xian-yang-shi: [18.6 19.9  8.1  7.3  7.8]
# RMSE for xian-yang-shi: 5.664979997752778
# -------------------------
# ADF Statistic: -11.324576604447241
# p-value: 1.151903658184394e-20
# Critical Values: {'1%': -4.331573, '5%': -3.23295, '10%': -2.7487}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.05 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=142.904, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=142.939, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.04 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=140.927, Time=0.00 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.129 seconds
# 预测值 for ha-er-bin-shi: [77.40000153 77.40000153 77.40000153 77.40000153 77.40000153]
# 真实值 for ha-er-bin-shi: [96.3 97.1 66.5 64.  60.9]
# RMSE for ha-er-bin-shi: 16.22294678285481
# -------------------------
# ADF Statistic: 0.657965175784227
# p-value: 0.988960556453012
# Critical Values: {'1%': -4.331573, '5%': -3.23295, '10%': -2.7487}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.06 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=141.421, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=143.151, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=142.497, Time=0.02 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=139.481, Time=0.00 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.106 seconds
# 预测值 for tang-shan-shi: [36.59999847 36.59999847 36.59999847 36.59999847 36.59999847]
# 真实值 for tang-shan-shi: [55.  50.  18.2 22.9 23.9]
# RMSE for tang-shan-shi: 15.528425241424777
# -------------------------
# ADF Statistic: -3.2249904288200537
# p-value: 0.01858294681439672
# Critical Values: {'1%': -4.068853732362312, '5%': -3.1271488757396453, '10%': -2.7017297633136095}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.06 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=102.429, Time=0.00 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=104.391, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.05 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=100.444, Time=0.01 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.132 seconds
# 预测值 for shang-qiu-shi: [12.89999962 12.89999962 12.89999962 12.89999962 12.89999962]
# 真实值 for shang-qiu-shi: [20.3 19.8  9.4 10.   9.8]
# RMSE for shang-qiu-shi: 5.150533629242192
# -------------------------
# ADF Statistic: -2.6317310957688407
# p-value: 0.08661481248532532
# Critical Values: {'1%': -4.331573, '5%': -3.23295, '10%': -2.7487}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.06 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=130.628, Time=0.00 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=132.034, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.03 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=128.664, Time=0.00 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.120 seconds
# 预测值 for jia-xing-shi: [36.70000076 36.70000076 36.70000076 36.70000076 36.70000076]
# 真实值 for jia-xing-shi: [46.2 49.3 28.8 26.9 34.5]
# RMSE for jia-xing-shi: 9.080748993823123
# -------------------------
# ADF Statistic: 0.5406072406124373
# p-value: 0.9860564379794936
# Critical Values: {'1%': -4.223238279489106, '5%': -3.189368925619835, '10%': -2.729839421487603}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.06 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=110.460, Time=0.00 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=112.097, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=110.988, Time=0.01 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=108.482, Time=0.00 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.096 seconds
# 预测值 for da-qing-shi: [15.30000019 15.30000019 15.30000019 15.30000019 15.30000019]
# 真实值 for da-qing-shi: [25.4 22.8 11.1 13.   9.7]
# RMSE for da-qing-shi: 6.519968982810002
# -------------------------
# ADF Statistic: -4.647822996383325
# p-value: 0.0001053432841884198
# Critical Values: {'1%': -4.137829282407408, '5%': -3.1549724074074077, '10%': -2.7144769444444443}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.06 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=153.168, Time=0.00 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=155.090, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=154.955, Time=0.03 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=151.200, Time=0.01 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.129 seconds
# 预测值 for da-lian-shi: [65.19999695 65.19999695 65.19999695 65.19999695 65.19999695]
# 真实值 for da-lian-shi: [94.6 89.  49.3 51.1 41.4]
# RMSE for da-lian-shi: 22.130792580816777
# -------------------------
# ADF Statistic: -0.3731311817740162
# p-value: 0.9144891755513125
# Critical Values: {'1%': -4.331573, '5%': -3.23295, '10%': -2.7487}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.07 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=175.829, Time=0.00 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=177.762, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=177.529, Time=0.03 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=173.872, Time=0.00 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.128 seconds
# 预测值 for tian-jin-shi: [129.6000061 129.6000061 129.6000061 129.6000061 129.6000061]
# 真实值 for tian-jin-shi: [171.5 186.8  87.9  77.9 103. ]
# RMSE for tian-jin-shi: 45.048396906469364
# -------------------------
# ADF Statistic: 0.6288558164314699
# p-value: 0.9883056959066805
# Critical Values: {'1%': -4.331573, '5%': -3.23295, '10%': -2.7487}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.06 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=122.034, Time=0.00 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=124.014, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=123.962, Time=0.01 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=120.034, Time=0.00 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.097 seconds
# 预测值 for tai-yuan-shi: [41.70000076 41.70000076 41.70000076 41.70000076 41.70000076]
# 真实值 for tai-yuan-shi: [55.3 55.3 40.2 38.2 40.5]
# RMSE for tai-yuan-shi: 8.784758605940716
# -------------------------
# ADF Statistic: -5.5824793199514975
# p-value: 1.3865253043456615e-06
# Critical Values: {'1%': -4.137829282407408, '5%': -3.1549724074074077, '10%': -2.7144769444444443}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.06 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=118.964, Time=0.00 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=120.797, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=120.520, Time=0.01 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=116.980, Time=0.01 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.102 seconds
# 预测值 for wei-hai-shi: [19. 19. 19. 19. 19.]
# 真实值 for wei-hai-shi: [27.  28.8 13.1 15.9 11.9]
# RMSE for wei-hai-shi: 7.139607668871272
# -------------------------
# ADF Statistic: 0.5811350484255451
# p-value: 0.9871412917277854
# Critical Values: {'1%': -4.331573, '5%': -3.23295, '10%': -2.7487}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.05 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=92.614, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=94.572, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=94.505, Time=0.01 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=90.628, Time=0.01 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.086 seconds
# 预测值 for ning-de-shi: [10.69999981 10.69999981 10.69999981 10.69999981 10.69999981]
# 真实值 for ning-de-shi: [16.6 16.5  8.8  8.9  8.3]
# RMSE for ning-de-shi: 4.026412953747917
# -------------------------
# ADF Statistic: -1.1199594161621065
# p-value: 0.7070470460260206
# Critical Values: {'1%': -4.331573, '5%': -3.23295, '10%': -2.7487}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.05 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=156.210, Time=0.00 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=158.204, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=158.197, Time=0.02 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=154.210, Time=0.00 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.094 seconds
# 预测值 for ning-bo-shi: [61.59999847 61.59999847 61.59999847 61.59999847 61.59999847]
# 真实值 for ning-bo-shi: [96.  84.2 58.2 52.8 58.4]
# RMSE for ning-bo-shi: 18.938637688534055
# -------------------------
# ADF Statistic: -5.13857724121512
# p-value: 1.1719650764997385e-05
# Critical Values: {'1%': -3.7238633119999998, '5%': -2.98648896, '10%': -2.6328004}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=337.855, Time=0.03 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=416.269, Time=0.00 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=335.981, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.04 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=414.306, Time=0.01 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=337.820, Time=0.03 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=339.731, Time=0.05 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=334.022, Time=0.01 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=335.862, Time=0.02 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=335.897, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=inf, Time=0.02 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=inf, Time=0.06 sec
#
# Best model:  ARIMA(1,1,0)(0,0,0)[0]
# Total fit time: 0.287 seconds
# 预测值 for su-zhou-shi: [ 16.00099493 101.09684738  19.91539982  97.36250492  23.47796273
#   93.96381973  26.72030857  90.87062163  29.67121972  88.05545225]
# 真实值 for su-zhou-shi: [ 14.8 135.8  14.2 141.4   7.3  73.7   7.6  69.2   5.8  89.8]
# RMSE for su-zhou-shi: 22.930650615826192
# -------------------------
# ADF Statistic: -3.131457555164153
# p-value: 0.024311093779460217
# Critical Values: {'1%': -4.331573, '5%': -3.23295, '10%': -2.7487}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.07 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=107.659, Time=0.00 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=109.641, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=109.620, Time=0.01 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=105.772, Time=0.01 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.109 seconds
# 预测值 for su-qian-shi: [14.69999981 14.69999981 14.69999981 14.69999981 14.69999981]
# 真实值 for su-qian-shi: [18.6 18.   9.7  7.8  8.4]
# RMSE for su-qian-shi: 5.261178629566259
# -------------------------
# ADF Statistic: -1.140712291334674
# p-value: 0.6985663834928743
# Critical Values: {'1%': -4.331573, '5%': -3.23295, '10%': -2.7487}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.05 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=135.938, Time=0.00 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=137.599, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.04 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=133.941, Time=0.01 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.122 seconds
# 预测值 for chang-zhou-shi: [42.59999847 42.59999847 42.59999847 42.59999847 42.59999847]
# 真实值 for chang-zhou-shi: [63.4 59.9 37.6 29.5 33.2]
# RMSE for chang-zhou-shi: 14.261137048189102
# -------------------------
# ADF Statistic: -4.633876375967455
# p-value: 0.00011181903633851975
# Critical Values: {'1%': -4.068853732362312, '5%': -3.1271488757396453, '10%': -2.7017297633136095}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.08 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=176.846, Time=0.00 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=178.825, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=178.784, Time=0.02 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=174.948, Time=0.01 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.143 seconds
# 预测值 for guang-zhou-shi: [149.80000305 149.80000305 149.80000305 149.80000305 149.80000305]
# 真实值 for guang-zhou-shi: [210.2 214.8 106.1 114.9 103.5]
# RMSE for guang-zhou-shi: 51.272897425208875
# -------------------------
# ADF Statistic: 0.03316546723669544
# p-value: 0.9611904045700794
# Critical Values: {'1%': -4.331573, '5%': -3.23295, '10%': -2.7487}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.06 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=120.283, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=122.226, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.03 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=118.291, Time=0.01 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.130 seconds
# 预测值 for nei-lu-CDC-suo-zai-cheng-shi: [34.20000076 34.20000076 34.20000076 34.20000076 34.20000076]
# 真实值 for nei-lu-CDC-suo-zai-cheng-shi: [42.2 49.  29.4 28.3 29.3]
# RMSE for nei-lu-CDC-suo-zai-cheng-shi: 8.542833503730613
# -------------------------
# ADF Statistic: -4.764948300963138
# p-value: 6.343512455378687e-05
# Critical Values: {'1%': -4.137829282407408, '5%': -3.1549724074074077, '10%': -2.7144769444444443}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.09 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=87.356, Time=0.00 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=88.848, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=88.355, Time=0.02 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=85.406, Time=0.01 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.137 seconds
# 预测值 for zhang-jia-kou-shi: [11.19999981 11.19999981 11.19999981 11.19999981 11.19999981]
# 真实值 for zhang-jia-kou-shi: [16.  14.6  8.1  7.5  9.4]
# RMSE for zhang-jia-kou-shi: 3.4968557719638858
# -------------------------
# ADF Statistic: -0.10852402273712708
# p-value: 0.9485828614149711
# Critical Values: {'1%': -4.223238279489106, '5%': -3.189368925619835, '10%': -2.729839421487603}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=139.172, Time=0.07 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=138.206, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=139.890, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=139.161, Time=0.02 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=136.269, Time=0.00 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.118 seconds
# 预测值 for xu-zhou-shi: [38.29999924 38.29999924 38.29999924 38.29999924 38.29999924]
# 真实值 for xu-zhou-shi: [55.2 52.3 25.5 32.2 30.3]
# RMSE for xu-zhou-shi: 12.22014740850322
# -------------------------
# ADF Statistic: -7.2208079865393255
# p-value: 2.1138522182347123e-10
# Critical Values: {'1%': -4.137829282407408, '5%': -3.1549724074074077, '10%': -2.7144769444444443}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.06 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=112.456, Time=0.00 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=114.288, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=114.035, Time=0.02 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=110.492, Time=0.01 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.100 seconds
# 预测值 for de-zhou-shi: [14.39999962 14.39999962 14.39999962 14.39999962 14.39999962]
# 真实值 for de-zhou-shi: [20.9 21.3  8.4  7.3  7.8]
# RMSE for de-zhou-shi: 6.630685923150226
# -------------------------
# ADF Statistic: -3.0645727802601135
# p-value: 0.029288491772605466
# Critical Values: {'1%': -4.223238279489106, '5%': -3.189368925619835, '10%': -2.729839421487603}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=119.191, Time=0.03 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=116.224, Time=0.00 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=118.039, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=117.686, Time=0.02 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=114.311, Time=0.00 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.068 seconds
# 预测值 for hui-zhou-shi: [25.29999924 25.29999924 25.29999924 25.29999924 25.29999924]
# 真实值 for hui-zhou-shi: [32.3 32.6 17.1 13.8 17.4]
# RMSE for hui-zhou-shi: 8.53451746885605
# -------------------------
# ADF Statistic: 0.6470715253403764
# p-value: 0.9887201860287187
# Critical Values: {'1%': -4.331573, '5%': -3.23295, '10%': -2.7487}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.05 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=162.392, Time=0.00 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=164.181, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=163.558, Time=0.02 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=160.428, Time=0.01 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.108 seconds
# 预测值 for cheng-du-shi: [162.6000061 162.6000061 162.6000061 162.6000061 162.6000061]
# 真实值 for cheng-du-shi: [193.4 201.7 153.3 131.6 149. ]
# RMSE for cheng-du-shi: 27.239305258699574
# -------------------------
# ADF Statistic: -0.7134969085603522
# p-value: 0.8432224912169268
# Critical Values: {'1%': -4.331573, '5%': -3.23295, '10%': -2.7487}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.06 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=123.273, Time=0.00 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=124.941, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=124.353, Time=0.02 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=121.312, Time=0.01 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.108 seconds
# 预测值 for yang-zhou-shi: [19.29999924 19.29999924 19.29999924 19.29999924 19.29999924]
# 真实值 for yang-zhou-shi: [32.2 32.6 11.5 11.3  9. ]
# RMSE for yang-zhou-shi: 10.716622380174586
# -------------------------
# ADF Statistic: -14.081888726315382
# p-value: 2.8192128214663404e-26
# Critical Values: {'1%': -4.331573, '5%': -3.23295, '10%': -2.7487}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.05 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=92.291, Time=0.00 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=93.818, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.05 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=90.291, Time=0.01 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.129 seconds
# 预测值 for cheng-de-shi: [17.20000076 17.20000076 17.20000076 17.20000076 17.20000076]
# 真实值 for cheng-de-shi: [21.5 19.3 14.9 15.3 13. ]
# RMSE for cheng-de-shi: 3.1445190690274245
# -------------------------
# ADF Statistic: -6.4670449778291035
# p-value: 1.3968791840694562e-08
# Critical Values: {'1%': -4.137829282407408, '5%': -3.1549724074074077, '10%': -2.7144769444444443}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.04 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=108.226, Time=0.00 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=109.896, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=109.565, Time=0.01 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=106.268, Time=0.00 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.079 seconds
# 预测值 for jie-yang-shi: [15.89999962 15.89999962 15.89999962 15.89999962 15.89999962]
# 真实值 for jie-yang-shi: [20.4 19.8 11.7 10.6 12.5]
# RMSE for jie-yang-shi: 4.306970739190408
# -------------------------
# ADF Statistic: -1.0225390123217764
# p-value: 0.7449552129036885
# Critical Values: {'1%': -4.223238279489106, '5%': -3.189368925619835, '10%': -2.729839421487603}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=105.076, Time=0.02 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=103.161, Time=0.00 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=104.312, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=103.504, Time=0.01 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=101.289, Time=0.01 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.058 seconds
# 预测值 for xin-xiang-shi: [18.29999924 18.29999924 18.29999924 18.29999924 18.29999924]
# 真实值 for xin-xiang-shi: [21.9 23.7 12.3 12.8 10.2]
# RMSE for xin-xiang-shi: 5.898813236946143
# -------------------------
# ADF Statistic: 1.4516035815159098
# p-value: 0.9973364112576438
# Critical Values: {'1%': -4.331573, '5%': -3.23295, '10%': -2.7487}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.07 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=154.215, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=156.183, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=156.143, Time=0.03 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=152.276, Time=0.01 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.143 seconds
# 预测值 for wu-xi-shi: [64.90000153 64.90000153 64.90000153 64.90000153 64.90000153]
# 真实值 for wu-xi-shi: [89.  82.1 47.9 45.3 48.1]
# RMSE for wu-xi-shi: 19.14183906385662
# -------------------------
# ADF Statistic: 0.4400784952741412
# p-value: 0.9829334234083065
# Critical Values: {'1%': -4.331573, '5%': -3.23295, '10%': -2.7487}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=100.055, Time=0.05 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=97.321, Time=0.00 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=99.127, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=98.896, Time=0.02 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=95.425, Time=0.01 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.092 seconds
# 预测值 for ri-zhao-shi: [13.39999962 13.39999962 13.39999962 13.39999962 13.39999962]
# 真实值 for ri-zhao-shi: [16.2 16.3  9.1  9.3  7.3]
# RMSE for ri-zhao-shi: 4.213311903050064
# -------------------------
# ADF Statistic: -0.20696113667263324
# p-value: 0.9376867658513655
# Critical Values: {'1%': -4.223238279489106, '5%': -3.189368925619835, '10%': -2.729839421487603}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=143.574, Time=0.04 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=141.239, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=143.156, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=142.709, Time=0.02 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=139.263, Time=0.01 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.107 seconds
# 预测值 for kun-ming-shi: [40.20000076 40.20000076 40.20000076 40.20000076 40.20000076]
# 真实值 for kun-ming-shi: [62.9 57.5 29.9 30.6 24.2]
# RMSE for kun-ming-shi: 15.930034771705909
# -------------------------
# ADF Statistic: -3.662489637349718
# p-value: 0.004672798153016094
# Critical Values: {'1%': -3.889265672705068, '5%': -3.0543579727254224, '10%': -2.66698384083045}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.16 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=193.331, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=189.892, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.05 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=191.354, Time=0.01 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=190.588, Time=0.05 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.12 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=187.903, Time=0.02 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=188.588, Time=0.02 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=inf, Time=0.04 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=inf, Time=0.02 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=inf, Time=0.07 sec
#
# Best model:  ARIMA(1,1,0)(0,0,0)[0]
# Total fit time: 0.586 seconds
# 预测值 for hang-zhou-shi: [566.1338652  561.34375991 563.82865317 562.53960123 563.20830396]
# 真实值 for hang-zhou-shi: [593.6 678.7 564.3 520.4 645.8]
# RMSE for hang-zhou-shi: 68.00621957140922
# -------------------------
# ADF Statistic: -3.2720142181941414
# p-value: 0.016176735696165272
# Critical Values: {'1%': -4.331573, '5%': -3.23295, '10%': -2.7487}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.09 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=161.639, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=163.637, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=163.636, Time=0.03 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=159.738, Time=0.01 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.160 seconds
# 预测值 for wu-han-shi: [115.09999847 115.09999847 115.09999847 115.09999847 115.09999847]
# 真实值 for wu-han-shi: [155.5 149.5  98.   87.   89.7]
# RMSE for wu-han-shi: 30.141997836396616
# -------------------------
# ADF Statistic: -5.188759916918805
# p-value: 9.268723484370144e-06
# Critical Values: {'1%': -4.137829282407408, '5%': -3.1549724074074077, '10%': -2.7144769444444443}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.03 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=110.078, Time=0.00 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=112.059, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=112.032, Time=0.01 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=108.092, Time=0.01 sec
#
# ...
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=416.269, Time=0.00 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=335.981, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.04 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=414.306, Time=0.01 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=337.820, Time=0.02 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=339.731, Time=0.04 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=334.022, Time=0.01 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=335.862, Time=0.01 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=335.897, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=inf, Time=0.02 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=inf, Time=0.05 sec
#
# Best model:  ARIMA(1,1,0)(0,0,0)[0]
# Total fit time: 0.245 seconds
# 预测值 for su-zhou-shi: [ 16.00099493 101.09684738  19.91539982  97.36250492  23.47796273
#   93.96381973  26.72030857  90.87062163  29.67121972  88.05545225]
# 真实值 for su-zhou-shi: [ 14.8 135.8  14.2 141.4   7.3  73.7   7.6  69.2   5.8  89.8]
# RMSE for su-zhou-shi: 22.930650615826192
# -------------------------
# ADF Statistic: -1.2185191621229816
# p-value: 0.6655789354084221
# Critical Values: {'1%': -4.223238279489106, '5%': -3.189368925619835, '10%': -2.729839421487603}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.05 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=111.176, Time=0.00 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=113.175, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=113.170, Time=0.01 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=109.238, Time=0.00 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.083 seconds
# 预测值 for he-ze-shi: [14.69999981 14.69999981 14.69999981 14.69999981 14.69999981]
# 真实值 for he-ze-shi: [22.2 22.9  9.6  9.7 11. ]
# RMSE for he-ze-shi: 6.134981726609126
# -------------------------
# ADF Statistic: -1.5825826353600445
# p-value: 0.4923366535791954
# Critical Values: {'1%': -4.331573, '5%': -3.23295, '10%': -2.7487}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.05 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=111.891, Time=0.00 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=113.614, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=113.026, Time=0.01 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=109.942, Time=0.01 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.085 seconds
# 预测值 for heng-yang-shi: [12. 12. 12. 12. 12.]
# 真实值 for heng-yang-shi: [20.5 21.1  7.7  7.9  7.2]
# RMSE for heng-yang-shi: 6.532993335862372
# -------------------------
# ADF Statistic: -1.0344145360209194
# p-value: 0.7405064159120164
# Critical Values: {'1%': -4.331573, '5%': -3.23295, '10%': -2.7487}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.09 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=122.648, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=124.632, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=124.617, Time=0.04 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=120.706, Time=0.01 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.169 seconds
# 预测值 for xiang-yang-shi: [19. 19. 19. 19. 19.]
# 真实值 for xiang-yang-shi: [28.2 31.7 12.2 11.7  9.7]
# RMSE for xiang-yang-shi: 9.294622556544628
# -------------------------
# ADF Statistic: -1.8830610737648135
# p-value: 0.34007119067455677
# Critical Values: {'1%': -4.223238279489106, '5%': -3.189368925619835, '10%': -2.729839421487603}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=143.349, Time=0.04 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=140.960, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=142.438, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=141.633, Time=0.02 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=139.341, Time=0.00 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.097 seconds
# 预测值 for xi-an-shi: [100.80000305 100.80000305 100.80000305 100.80000305 100.80000305]
# 真实值 for xi-an-shi: [104.3 111.5  80.1  79.4  74.7]
# RMSE for xi-an-shi: 18.408696358611305
# -------------------------
# ADF Statistic: -3.1205645723511872
# p-value: 0.02506827803773509
# Critical Values: {'1%': -3.889265672705068, '5%': -3.0543579727254224, '10%': -2.66698384083045}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.06 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=125.930, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=127.383, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.03 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=124.181, Time=0.00 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.130 seconds
# 预测值 for gui-yang-shi: [42. 42. 42. 42. 42.]
# 真实值 for gui-yang-shi: [50.6 38.9 29.2 30.3 33.1]
# RMSE for gui-yang-shi: 9.628187677612225
# -------------------------
# ADF Statistic: -4.89590270945826
# p-value: 3.552047839034412e-05
# Critical Values: {'1%': -4.137829282407408, '5%': -3.1549724074074077, '10%': -2.7144769444444443}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.05 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=103.952, Time=0.00 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=105.600, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=104.487, Time=0.01 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=101.953, Time=0.01 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.089 seconds
# 预测值 for gan-zhou-shi: [13.60000038 13.60000038 13.60000038 13.60000038 13.60000038]
# 真实值 for gan-zhou-shi: [21.3 22.4 10.9 10.5 10.4]
# RMSE for gan-zhou-shi: 5.724857733012504
# -------------------------
# ADF Statistic: -1.969184294000626
# p-value: 0.3002459698729395
# Critical Values: {'1%': -4.223238279489106, '5%': -3.189368925619835, '10%': -2.729839421487603}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.09 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=86.045, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=87.901, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=87.778, Time=0.01 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=84.084, Time=0.01 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.134 seconds
# 预测值 for yun-cheng-shi: [10. 10. 10. 10. 10.]
# 真实值 for yun-cheng-shi: [14.5 13.6  8.7  8.3  7.3]
# RMSE for yun-cheng-shi: 3.0026655346217344
# -------------------------
# ADF Statistic: 1.9775791626127954
# p-value: 0.9986430997801847
# Critical Values: {'1%': -4.331573, '5%': -3.23295, '10%': -2.7487}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.07 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=109.123, Time=0.00 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=109.971, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.04 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=107.123, Time=0.01 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.134 seconds
# 预测值 for lian-yun-gang-shi: [18.29999924 18.29999924 18.29999924 18.29999924 18.29999924]
# 真实值 for lian-yun-gang-shi: [27.4 24.4 17.1 17.  14.9]
# RMSE for lian-yun-gang-shi: 5.190568451960985
# -------------------------
# ADF Statistic: -0.7814928611786192
# p-value: 0.8244980460433877
# Critical Values: {'1%': -4.223238279489106, '5%': -3.189368925619835, '10%': -2.729839421487603}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.07 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=102.849, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=104.816, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=104.765, Time=0.01 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=100.946, Time=0.01 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.115 seconds
# 预测值 for xing-tai-shi: [13.30000019 13.30000019 13.30000019 13.30000019 13.30000019]
# 真实值 for xing-tai-shi: [16.6 16.1  8.   8.2  9.3]
# RMSE for xing-tai-shi: 4.214973505011541
# -------------------------
# ADF Statistic: 0.6063043569593605
# p-value: 0.9877699942907777
# Critical Values: {'1%': -4.331573, '5%': -3.23295, '10%': -2.7487}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.06 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=119.392, Time=0.00 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=121.373, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=121.335, Time=0.02 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=117.430, Time=0.01 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.103 seconds
# 预测值 for han-dan-shi: [17.10000038 17.10000038 17.10000038 17.10000038 17.10000038]
# 真实值 for han-dan-shi: [30.2 26.  12.7 12.6 14.4]
# RMSE for han-dan-shi: 7.716476039742758
# -------------------------
# ADF Statistic: -1.4198246735926634
# p-value: 0.5727358887663396
# Critical Values: {'1%': -4.331573, '5%': -3.23295, '10%': -2.7487}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=156.396, Time=0.04 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=153.539, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=155.405, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=155.092, Time=0.02 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=151.555, Time=0.01 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.099 seconds
# 预测值 for zheng-zhou-shi: [67. 67. 67. 67. 67.]
# 真实值 for zheng-zhou-shi: [ 88.4 101.   54.   58.2  56.1]
# RMSE for zheng-zhou-shi: 19.89577887464599
# -------------------------
# ADF Statistic: -7.3873055235280995
# p-value: 8.172688341424761e-11
# Critical Values: {'1%': -4.331573, '5%': -3.23295, '10%': -2.7487}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.05 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=170.174, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=172.021, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=171.431, Time=0.02 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=168.261, Time=0.01 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.112 seconds
# 预测值 for chong-qing-shi: [119.30000305 119.30000305 119.30000305 119.30000305 119.30000305]
# 真实值 for chong-qing-shi: [182.1 180.9  94.3  89.1  89.9]
# RMSE for chong-qing-shi: 45.032876038694546
# -------------------------
# ADF Statistic: -2.5142526584006264
# p-value: 0.11204489967502801
# Critical Values: {'1%': -4.137829282407408, '5%': -3.1549724074074077, '10%': -2.7144769444444443}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.07 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=137.362, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=138.633, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.04 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=135.509, Time=0.01 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.159 seconds
# 预测值 for jin-hua-shi: [60.70000076 60.70000076 60.70000076 60.70000076 60.70000076]
# 真实值 for jin-hua-shi: [62.4 66.1 43.7 43.8 47.9]
# RMSE for jin-hua-shi: 12.41370218684355
# -------------------------
# ADF Statistic: -5.215001043469998
# p-value: 8.19279810825011e-06
# Critical Values: {'1%': -4.137829282407408, '5%': -3.1549724074074077, '10%': -2.7144769444444443}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=121.377, Time=0.03 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=120.276, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=121.770, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=120.292, Time=0.02 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=118.371, Time=0.00 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.073 seconds
# 预测值 for zhen-jiang-shi: [21.79999924 21.79999924 21.79999924 21.79999924 21.79999924]
# 真实值 for zhen-jiang-shi: [29.8 30.  13.6 13.1 12.8]
# RMSE for zhen-jiang-shi: 8.428166546349724
# -------------------------
# ADF Statistic: -3.0907932664259143
# p-value: 0.02724207312006055
# Critical Values: {'1%': -4.01203360058309, '5%': -3.1041838775510207, '10%': -2.6909873469387753}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=140.346, Time=0.02 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=138.640, Time=0.00 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=139.208, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=138.365, Time=0.02 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=136.712, Time=0.00 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.084 seconds
# 预测值 for chang-chun-shi: [55.20000076 55.20000076 55.20000076 55.20000076 55.20000076]
# 真实值 for chang-chun-shi: [67.9 72.4 48.8 46.4 37.8]
# RMSE for chang-chun-shi: 13.253604074574488
# -------------------------
# ADF Statistic: -5.443275219406856
# p-value: 2.7458934932492113e-06
# Critical Values: {'1%': -4.137829282407408, '5%': -3.1549724074074077, '10%': -2.7144769444444443}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=156.867, Time=0.07 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=154.598, Time=0.00 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=156.235, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=155.447, Time=0.02 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=152.644, Time=0.01 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.131 seconds
# 预测值 for chang-sha-shi: [68.80000305 68.80000305 68.80000305 68.80000305 68.80000305]
# 真实值 for chang-sha-shi: [91.3 86.9 48.3 51.2 52. ]
# RMSE for chang-sha-shi: 19.21515175204855
# -------------------------
# ADF Statistic: 0.1414137771679542
# p-value: 0.9687774778123668
# Critical Values: {'1%': -4.331573, '5%': -3.23295, '10%': -2.7487}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.08 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=91.611, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=93.605, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.05 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=89.621, Time=0.01 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.163 seconds
# 预测值 for fu-yang-shi: [12.39999962 12.39999962 12.39999962 12.39999962 12.39999962]
# 真实值 for fu-yang-shi: [16.3 16.4  9.4  8.2  9.3]
# RMSE for fu-yang-shi: 3.6731455695274406
# -------------------------
# ADF Statistic: -6.169392071204441
# p-value: 6.863822699178636e-08
# Critical Values: {'1%': -4.331573, '5%': -3.23295, '10%': -2.7487}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=155.002, Time=0.04 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=151.558, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=153.555, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.03 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=149.641, Time=0.01 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.093 seconds
# 预测值 for qing-dao-shi: [99.59999847 99.59999847 99.59999847 99.59999847 99.59999847]
# 真实值 for qing-dao-shi: [122.2 136.5  79.7  64.7  78.7]
# RMSE for qing-dao-shi: 28.0114272205406
# -------------------------
# ADF Statistic: -0.8999374065870965
# p-value: 0.7879930298819928
# Critical Values: {'1%': -4.223238279489106, '5%': -3.189368925619835, '10%': -2.729839421487603}
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.05 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=109.264, Time=0.00 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=110.790, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=110.223, Time=0.02 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=107.377, Time=0.01 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.097 seconds
# 预测值 for an-shan-shi: [21.89999962 21.89999962 21.89999962 21.89999962 21.89999962]
# 真实值 for an-shan-shi: [30.5 26.7 15.7 15.3 13. ]
# RMSE for an-shan-shi: 7.186236857204685
# -------------------------
# {1389.377559618295}
# {13.107335468097123}
